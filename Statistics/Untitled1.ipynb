# %% [markdown]
# ## Солдатов Денис №34
#
# # 1. Метод максимального правдоподобия
# В прикреплённом Word-файле
#
# # 2. Задача 1.
#
# Для подсчёта количества различных слов (перестановок) используется формула:
# 𝑃 = 𝑛!/𝑘1!⋅𝑘2!⋅⋯⋅𝑘𝑚!, где:
#
#
# 𝑛 — общее количество букв,
# 𝑘
# 1
# ,
# 𝑘
# 2
# ,
# …
# ,
# 𝑘
# 𝑚
# — количество повторений одинаковых букв.
#
# А) Фамилия: Солдатов
# Посчитаем общее количество букв:
#
# 𝑛=8.
# Подсчитаем количество повторяющихся букв:
# С: 1,
# о: 2,
# л: 1,
# д: 1,
# а: 1,
# т: 1,
# в: 1.
# Подставим в формулу:
#
# 𝑃=8!/2!=40320/2=20160.
#
# Итак, количество различных слов из букв фамилии: 20160.
#
# Б) Имя: Денис
# Посчитаем общее количество букв:
#
# 𝑛=5.
# Подсчитаем количество повторяющихся букв:
# Д: 1,
# е: 1,
# н: 1,
# и: 1,
# с: 1.
# Так как все буквы уникальны, формула упрощается:
#
# P=5!=120.
# Итак, количество различных слов из букв имени: 120.
#
# В) Имя и фамилия вместе: СолдатовДенис
# Посчитаем общее количество букв:
#
# 𝑛=13.
# Подсчитаем количество повторяющихся букв:
# С: 1,
# о: 2,
# л: 1,
# д: 2,
# а: 1,
# т: 1,
# в: 1,
# Д: 1,
# е: 1,
# н: 1,
# и: 1,
# с: 1.
# Подставим в формулу:
#
# 𝑃=13!/2!⋅2!=6227020800/4=1556755200.
#
# Итак, количество различных слов из букв имени и фамилии вместе: 1556755200.
#
# Итог:
# А) 20160 слов.
# Б) 120 слов.
# В) 1556755200 слов.
#
# # Задача 2.
#
# Создаём датасет со 100 значениями:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from scipy import stats
import random

dataset = np.random.randint(-34, 35, 100)

# Вычисление медианы
med = np.median(dataset)

# Вычисление моды
var = np.var(dataset)

# Вычисление среднего
mn = np.mean(dataset)

# Вывод результатов
print("Медиана:", med)
print("Дисперсия: ", var)
print("Среднее:", mn)
# Out:
# Медиана: 0.5
# Дисперсия:  343.6691
# Среднее: 0.03
